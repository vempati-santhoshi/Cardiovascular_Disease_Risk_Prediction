# %% [markdown]
# <a href="https://colab.research.google.com/github/vempati-santhoshi/Cardiovascular_Disease_Risk_Prediction/blob/main/Youtube_data_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
API_KEY='AIzaSyAoy4fQHYC_R2bWa7zTlw7cU2uLIEz5Dk0'
COUNTRY_CODE='US'
url='https://www.googleapis.com/youtube/v3/videos'

# %%
params={
    'part':'snippet,statistics',
    'chart':'mostPopular',
    'regionCode':COUNTRY_CODE,
    'maxResults':50,
    'key':API_KEY
}

# %%
response=requests.get(url,params=params)

# %%
print("Status Code:", response.status_code)
print("Response:", response.text)
# Out:
# Status Code: 200
# Response: {
#   "kind": "youtube#videoListResponse",
#   "etag": "0lfqlEIduvgamVNo5I7oH8Jzuc4",
#   "items": [
#     {
#       "kind": "youtube#video",
#       "etag": "QW7lopVq3JhLsDGdlvr3yUygfMQ",
#       "id": "m08TxIsFTRI",
#       "snippet": {
#         "publishedAt": "2025-06-30T12:21:25Z",
#         "channelId": "UCf5CjDJvsFvtVIhkfmKAwAA",
#         "title": "Project Hail Mary - Official Trailer",
# ...

# %%
if response.status_code ==200:
  data=response.json()
  for idx, video in enumerate(data['items'],1):
    title=video['snippet']['title']
    channel=video['snippet']['channelTitle']
    views=video['statistics'].get('viewCount','N/A')
    print(f"{idx}.{title}|Channel:{channel}|Views:{views}")
else:
  print(f"Error:{response.status_code}")
  print(response.json())
# Out:
# 1.Project Hail Mary - Official Trailer|Channel:Amazon MGM Studios|Views:9540881
# 2.The CyberClash Is On! Clash of Clans New Season|Channel:Clash of Clans|Views:1002445
# 3.Manchester City vs Al-Hilal - FULL Match Highlights & Goals | 2025 FIFA Club World Cup|Channel:House of Highlights|Views:440768
# 4.This mechanism shrinks when pulled|Channel:Veritasium|Views:3413016
# 5.LEGENDARY PHYSICAL 1v1 Against CashNasty Rematch 2025!|Channel:FlightReacts|Views:643288
# 6.1 Conservative vs 20 Feminists (Ft. Candace Owens)|Channel:Jubilee|Views:2615177
# 7.WE GAVE MICHAEL REEVES A GUN…|Channel:OfflineTV|Views:760464
# 8.BABYMONSTER - ‘HOT SAUCE’ M/V|Channel:BABYMONSTER|Views:7567462
# 9.Bryan Kohberger pleads guilty to all counts|Channel:WNEP|Views:734524
# 10.Ilia Topuria Knocks Out Charles Oliveira 👊 | UFC 317|Channel:UFC|Views:12544452
# 11.So It Begins...Is This A Real Band Or AI?|Channel:Rick Beato|Views:698834
# ...
